# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding='latin-1')
users.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.describe(include=['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# #### 3.1 Ноутбуков от какой компании больше всего в наборе данных?

# %%
df['Company'].sort_values()
# Out:
# 651       Acer
# 78        Acer
# 324       Acer
# 326       Acer
# 371       Acer
#          ...
# 1120      Vero
# 877     Xiaomi
# 184     Xiaomi
# 514     Xiaomi
# 192     Xiaomi
# Name: Company, Length: 1303, dtype: object

# %%
df.Company.sort_values()
# Out:
# 651       Acer
# 78        Acer
# 324       Acer
# 326       Acer
# 371       Acer
#          ...
# 1120      Vero
# 877     Xiaomi
# 184     Xiaomi
# 514     Xiaomi
# 192     Xiaomi
# Name: Company, Length: 1303, dtype: object

# %%
df.Company.value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %% [markdown]
# #### 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
df.Price_euros.max()
# Out:
# 6099.0

# %%
df.Price_euros.min()
# Out:
# 174.0

# %% [markdown]
# ##### 3.3 Какой самый дорогой ноутбук в данных?

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %%
df.sort_values('Price_euros', ascending=False).head(1)
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %% [markdown]
# #### 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
#
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость Если таких ноутбуков несколько, то выводите их всех

# %%
df[df['Inches'] == df['Inches'].min()][["Company", "TypeName", "Inches", "Price_euros"]]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# #### 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df['Company']=='HP'].sort_values('Price_euros', ascending=False).head()
# Out:
#       laptop_ID Company          Product            TypeName  Inches  \
# 749         758      HP         Zbook 17         Workstation    17.3
# 1136       1151      HP         ZBook 17         Workstation    17.3
# 911         924      HP  Elitebook Folio           Ultrabook    12.5
# 1103       1118      HP         ZBook 17         Workstation    17.3
# 857         868      HP   EliteBook x360  2 in 1 Convertible    13.3
#
#                          ScreenResolution                            Cpu  \
# 749           IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz
# 1136          IPS Panel Full HD 1920x1080    Intel Core i7 6700HQ 2.6GHz
# 911   4K Ultra HD / Touchscreen 3840x2160       Intel Core M 6Y75 1.2GHz
# 1103          IPS Panel Full HD 1920x1080    Intel Core i7 6700HQ 2.6GHz
# 857       Full HD / Touchscreen 1920x1080     Intel Core i7 7600U 2.8GHz
#
#        Ram     Memory                    Gpu       OpSys  Weight  Price_euros
# ...

# %%
df[df['Company']=='HP'].sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# laptop_ID                                     758
# Company                                        HP
# Product                                  Zbook 17
# TypeName                              Workstation
# Inches                                       17.3
# ScreenResolution      IPS Panel Full HD 1920x1080
# Cpu                 Intel Xeon E3-1535M v5 2.9GHz
# Ram                                          16GB
# Memory                                  256GB SSD
# Gpu                          Nvidia Quadro M2000M
# OpSys                                   Windows 7
# Weight                                        3kg
# Price_euros                                4389.0
# Name: 749, dtype: object

# %%
df[df['Company']=='HP'].sort_values('Price_euros', ascending=False).iloc[0:3]
# Out:
#       laptop_ID Company          Product     TypeName  Inches  \
# 749         758      HP         Zbook 17  Workstation    17.3
# 1136       1151      HP         ZBook 17  Workstation    17.3
# 911         924      HP  Elitebook Folio    Ultrabook    12.5
#
#                          ScreenResolution                            Cpu  \
# 749           IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz
# 1136          IPS Panel Full HD 1920x1080    Intel Core i7 6700HQ 2.6GHz
# 911   4K Ultra HD / Touchscreen 3840x2160       Intel Core M 6Y75 1.2GHz
#
#        Ram     Memory                    Gpu       OpSys  Weight  Price_euros
# 749   16GB  256GB SSD   Nvidia Quadro M2000M   Windows 7     3kg       4389.0
# 1136   8GB  256GB SSD   Nvidia Quadro M3000M   Windows 7     3kg       3949.4
# 911    8GB  240GB SSD  Intel HD Graphics 515  Windows 10  1.09kg       3100.0

# %% [markdown]
# #### 4.3 Как много ноутбуков Ultrabook с 8GB RAM?

# %%
df[(df['TypeName']=='Ultrabook') & (df['Ram'] == '8GB')]
# Out:
#       laptop_ID Company               Product   TypeName  Inches  \
# 0             1   Apple           MacBook Pro  Ultrabook    13.3
# 1             2   Apple           Macbook Air  Ultrabook    13.3
# 4             5   Apple           MacBook Pro  Ultrabook    13.3
# 7             8   Apple           Macbook Air  Ultrabook    13.3
# 9            10    Acer               Swift 3  Ultrabook    14.0
# ...         ...     ...                   ...        ...     ...
# 1236       1254      HP         EliteBook 840  Ultrabook    14.0
# 1241       1259    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261       1279    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275       1293    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# ...

# %%
df[(df['TypeName']=='Ultrabook') & (df['Ram'] == '8GB')].shape[0]
# Out:
# 140

# %% [markdown]
# #### 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?

# %%
df[
    ((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) &
    (df['OpSys'] == 'Windows 10') &
    (df['Price_euros'] <= 500)
]
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 74           76    Acer                             Aspire E5-475  Notebook
# 175         179    Dell                             Inspiron 3567  Notebook
# 256         261      HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook
# 292         297      HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook
# 313         318    Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook
# 365         371      HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook
# 571         578      HP            14-am079na (N3710/8GB/2TB/W10)  Notebook
# 595         602  Lenovo                         IdeaPad 110-15ISK  Notebook
# 634         642    Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook
# 702         710  Lenovo                         IdeaPad 320-15ABR  Notebook
# 1057       1071    Acer                            Aspire ES1-523  Notebook
# ...

# %%
df[
    ((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) &
    (df['OpSys'] == 'Windows 10') &
    (df['Price_euros'] <= 500)
].shape[0]
# Out:
# 13

# %%
df[
    ((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) &
    (df['OpSys'] == 'Windows 10') &
    (df['Price_euros'] <= 500)
].count()
# Out:
# laptop_ID           13
# Company             13
# Product             13
# TypeName            13
# Inches              13
# ScreenResolution    13
# Cpu                 13
# Ram                 13
# Memory              13
# Gpu                 13
# OpSys               13
# Weight              13
# Price_euros         13
# dtype: int64

# %% [markdown]
# #### 5.2 Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
df[
    (df['Company'] == 'MSI') &
    (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') &
    (~(df['Inches'] == 15.6))
]
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# ...

# %%
df[
    (df['Company'] == 'MSI') &
    (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') &
    (~(df['Inches'] == 15.6))
]['Price_euros']
# Out:
# 330     1199.00
# 393     1349.00
# 724     1348.48
# 917     1599.00
# 1156    1492.80
# Name: Price_euros, dtype: float64

# %%
df[
    (df['Company'] == 'MSI') &
    (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') &
    (~(df['Inches'] == 15.6))
].describe()
# Out:
#          laptop_ID  Inches  Price_euros
# count     5.000000     5.0     5.000000
# mean    714.600000    17.3  1397.656000
# std     353.727013     0.0   153.167946
# min     336.000000    17.3  1199.000000
# 25%     400.000000    17.3  1348.480000
# 50%     732.000000    17.3  1349.000000
# 75%     931.000000    17.3  1492.800000
# max    1174.000000    17.3  1599.000000

# %% [markdown]
# #### 5.3 В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
first = df[(df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz' )]['Price_euros'].mean()

# %%
second = df[(df['Cpu'] == 'Intel Core i7 7600U 2.8GHz' )]['Price_euros'].mean()

# %%
first < second
# Out:
# True

# %% [markdown]
# #### 5.4 Найдите самый легкий ноутбук Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
print(19 > 9, '19' > '9')
# Out:
# True False

# %%
df['Weight'] = df['Weight'].str.replace('kg', '')
df['Weight'] = df['Weight'].astype(float)

# %%
df[df['TypeName'] == 'Notebook']['Weight'].min()
# Out:
# 1.05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   float64
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
# !pip install jupyterthemes
# Out:
# ...
#      ---------------------------------------- 7.0/7.0 MB 5.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.7/46.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 49.6/49.6 kB ? eta 0:00:00
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork -T -N -kl
